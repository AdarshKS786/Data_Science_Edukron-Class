# %%
# note 1
# 7a=10
# this is not works variable cannot allows begining with number

# %%
a7=30
a7a=10
a7
# Out:
# 30

# %%
# note 2
a$a=10
# this type of special character is not allowed
# Out:
#   File "<ipython-input-3-be55e31797c5>", line 2
#     a$a=10
#      ^
# SyntaxError: invalid syntax

# %%
a_=30
a_
# Out:
# 30

# %%
import keyword
keyword.kwlist
# this are not allowed for variable
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
a=10
b=20.0
c=10.6+3j
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# complex

# %%
string = '''dara
science
machine learning
ai'''
# in this case single coats and double coats are not works only thriple coats are works
type(string)
# Out:
# str

# %%
string
# Out:
# 'dara\nscience\nmachine learning\nai'

# %%
"data sci 'ence"
# double coats is usefull to allows single coats behind in the stings
# Out:
# "data sci 'ence"

# %%
string="DATA SCIENCE"
string
# Out:
# 'DATA SCIENCE'

# %%
type(string)
# Out:
# str

# %%
string[0:2]
# Out:
# 'DA'

# %%
print(string[4:7])
# Out:
#  SC

# %%
string[-12:-6]
# Out:
# 'DATA S'

# %%
string[:4]
# Out:
# 'DATA'

# %%
string[-3:]
# Out:
# 'NCE'

# %%
string[:-9]
# Out:
# 'DAT'

# %%
string[-2:-11]
# note the string should need left to right
# Out:
# ''

# %%
string[-7:-2]
# Out:
# 'SCIEN'

# %%
string1="DATA SCIENCE"
string2="Data Analytics"
string3="Data Engineering"

# %%
string1.upper()
# Out:
# 'DATA SCIENCE'

# %%
string2.lower()
# Out:
# 'data analytics'

# %%
string3.lower()
# Out:
# 'data engineering'

# %%
string3.isupper()
# Out:
# False

# %%
string1.isupper()
# Out:
# True

# %%
string1.title()
# Out:
# 'Data Science'

# %%
string1="DAta Science. machine learning"

# %%
string1.capitalize()
# Out:
# 'Data science. machine learning'

# %%
string1.swapcase()
# Out:
# 'daTA sCIENCE. MACHINE LEARNING'

# %%
string1="data123"
string.isalpha()
# Out:
# False

# %%
string1.isalnum()
# Out:
# True

# %%
string1="dataengineering"
string1.isalpha()
# Out:
# True

# %%
string1="12345678"
string1.isnumeric()
# Out:
# True

# %%
string1="abc123"
string1.isnumeric()
# Out:
# False

# %%
string="data science"
string.startswith("data")
# Out:
# True

# %%
string="data science"
string.endswith("science")
# Out:
# True

# %%
string="data science"
string.startswith("science")
# Out:
# False

# %%
len(string)
# Out:
# 12

# %%
string.split()
# Out:
# ['data', 'science']

# %%
string.split("a")
# Out:
# ['d', 't', ' science']
