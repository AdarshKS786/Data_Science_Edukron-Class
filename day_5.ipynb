# %% [markdown]
# ## **Dictionaries**:

# %%
d={"key":10,"key1":20}

# %%
d
# Out:
# {'key': 10, 'key1': 20}

# %%
type(d)
# Out:
# dict

# %%
d={"key":10,"key":20}

# %%
d
# Out:
# {'key': 20}

# %%
d={10: [1,2,3,4]}      ### The data should not take list as first in dict

# %%
d
# Out:
# {10: [1, 2, 3, 4]}

# %%
my_dict={
    "name": "alice",
    "age": 25,
    "location": "Banglore"
}

# %%
my_dict["location"]
# Out:
# 'Banglore'

# %%
my_dict
# Out:
# {'name': 'alice', 'age': 25, 'location': 'Banglore'}

# %%
mixed_dict = {
    "name": "alice",
    101: [1,2,3,4],
    3.14: ["unit", "pi"],
    True: "active"

}

# %%
mixed_dict
# Out:
# {'name': 'alice', 101: [1, 2, 3, 4], 3.14: ['unit', 'pi'], True: 'active'}

# %%
mixed_dict[101][-1]
# Out:
# 4

# %%
employee = {
    "id": 1947,
    "name": "priya sharma",
    "department": {
        "name": "HR",
        "location": "banglore",
        "floor": 3
    }
}

# %%
employee["department"]["location"]
# Out:
# 'banglore'

# %%
mixed_dict = {
    "name": "alice",
    101: [1,2,3,4],
    3.14: ["unit", "pi"],
    True: "active",
    None: 0,
    (1,2): "tuple_key",
    "details": {
        "age": 25,
        "location": "banglore"
    },
    "scores": (95, 90, 85),
    "is_verified": False,
    "height":5.7
}

# %%
mixed_dict[1]
# Out:
# 'active'

# %%
temp={
   "lat":33.44,
   "lon":-94.04,
   "timezone":"America/Chicago",
   "timezone_offset":-18000,
   "current":{
      "dt":1684929490,
      "sunrise":1684926645,
      "sunset":1684977332,
      "temp":292.55,
      "feels_like":292.87,
      "pressure":1014,
      "humidity":89,
      "dew_point":290.69,
      "uvi":0.16,
      "clouds":53,
      "visibility":10000,
      "wind_speed":3.13,
      "wind_deg":93,
      "wind_gust":6.71,
      "weather":[
         {
            "id":803,
            "main":"Clouds",
            "description":"broken clouds",
            "icon":"04d"
         }
      ]
   } }

# %%
temp['current']['weather'][0]['description'].upper()
# Out:
# 'BROKEN CLOUDS'

# %%
d = {
    "name": "Likki",
    "age": 25,
    "location": "Bangalore"
}

# %%
d.values()
# Out:
# dict_values(['Likki', 25, 'Bangalore'])

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'location'])

# %%
d.items()
# Out:
# dict_items([('name', 'Likki'), ('age', 25), ('location', 'Bangalore')])

# %%
d
# Out:
# {'name': 'Likki', 'age': 25, 'location': 'Bangalore'}

# %%
d.get("age")
# Out:
# 25

# %%
d['name']
# Out:
# 'Likki'

# %%
d
# Out:
# {'name': 'Likki', 'age': 25, 'location': 'Bangalore'}

# %%
d.update({"name": "Priya"})

# %%
d
# Out:
# {'name': 'Priya', 'age': 25, 'location': 'Bangalore'}

# %%
d.pop("age")
# Out:
# 25

# %%
d
# Out:
# {'name': 'Priya', 'location': 'Bangalore'}

# %%
d.items()
# Out:
# dict_items([('name', 'Priya'), ('location', 'Bangalore')])

# %%
d.clear()

# %%
del d

# %%
d= {
    "name" : "aditya",
    "age" : 25,
    "location" : "bangalore"

}

# %%
d
# Out:
# {'name': 'aditya', 'age': 25, 'location': 'bangalore'}

# %%
d.popitem()
# Out:
# ('location', 'bangalore')

# %%
d
# Out:
# {'name': 'aditya', 'age': 25}

# %%
isinstance(d,dict)
# Out:
# True

# %%
d
# Out:
# {'name': 'aditya', 'age': 25}

# %%
isinstance(d['age'],int)
# Out:
# True

# %%
x=[1,2,3,4]

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
y = [1,1,2,2,2,3,3,4,5]
y.index(1)
# Out:
# 0

# %%
x={11,12,1,2,32,24,17}

# %%
x
# Out:
# {1, 2, 11, 12, 17, 24, 32}

# %%
del frozenset

# %%
y = frozenset([1, 1, 2, 2, 2, 3, 3, 4, 5, 20, 45, 13, 13])
print(y)
# Out:
# frozenset({1, 2, 3, 4, 5, 45, 13, 20})

# %%
# y.add(12). It will not modifys one it will set
