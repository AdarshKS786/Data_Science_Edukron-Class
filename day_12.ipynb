# %%
import numpy as np

retail_np_array=np.array([
    [1001, "laptop", 1, 50000, 50000],
    [1002, "mouse",2, 500, 1000],
    [1003, "keybord", 1, 1000, 1000],
    [1004, "monitor", 2, 7000, 14000],
    [1005, "Headphones", 1, 2000, 2000]

], dtype=object)
retail_np_array


# # Existing columns
# customer_id = retail_np_array[:, 0]
# product = retail_np_array[:, 1]
# quantities = retail_np_array[:, 2].astype(int)
# price = retail_np_array[:, 3].astype(int)
# total = retail_np_array[:, 4].astype(int)
# Out:
# array([[1001, 'laptop', 1, 50000, 50000],
#        [1002, 'mouse', 2, 500, 1000],
#        [1003, 'keybord', 1, 1000, 1000],
#        [1004, 'monitor', 2, 7000, 14000],
#        [1005, 'Headphones', 1, 2000, 2000]], dtype=object)

# %%
customer_id = retail_np_array[:, 0]
customer_id
# Out:
# array([1001, 1002, 1003, 1004, 1005], dtype=object)

# %%
product = retail_np_array[:, 1]
product
# Out:
# array(['laptop', 'mouse', 'keybord', 'monitor', 'Headphones'],
#       dtype=object)

# %%
quantities = retail_np_array[:, 2].astype(int)
quantities
# Out:
# array([1, 2, 1, 2, 1])

# %%
price = retail_np_array[:, 3].astype(int)
price
# Out:
# array([50000,   500,  1000,  7000,  2000])

# %%
total = retail_np_array[:, 4].astype(int)
total
# Out:
# array([50000,  1000,  1000, 14000,  2000])

# %%
retail_np_array.shape[0],
# Out:
# (5,)

# %%
np.sum(total),
# Out:
# (np.int64(68000),)

# %%
np.mean(total),
# Out:
# (np.float64(13600.0),)

# %%
product[np.argmax(total)],
# Out:
# ('laptop',)

# %%
product[np.argmin(total)],
# Out:
# ('mouse',)

# %%
np.mean(price),
# Out:
# (np.float64(12100.0),)

# %%
np.sum(quantities),
# Out:
# (np.int64(7),)

# %%
np.unique(product, return_counts=True)[0][np.argmax(np.unique(product, return_counts=True)[1])]
# Out:
# 'Headphones'

# %%
len(np.unique(product))
# Out:
# 5

# %%
len(np.unique(customer_id))
customer_id
# Out:
# array([1001, 1002, 1003, 1004, 1005], dtype=object)

# %%
product.tolist(),
# Out:
# (['laptop', 'mouse', 'keybord', 'monitor', 'Headphones'],)

# %%
# (prod:np.sum(totals[product == prod])) for prod in np.unique(product)

# %%
{prod}

# %%
np.max(price)
# Out:
# np.int64(50000)

# %%
np.min(price),
# Out:
# (np.int64(500),)

# %%
product[quantities>1].tolist(),
# Out:
# (['mouse', 'monitor'],)

# %%
customer_id[quantities>1].tolist(),
# Out:
# ([1002, 1004],)

# %%
np.sum(total[customer_id == 1002])
# Out:
# np.int64(1000)

# %%
product[price > 1000].tolist()
# Out:
# ['laptop', 'monitor', 'Headphones']

# %%
product[total > 2000].tolist()
# Out:
# ['laptop', 'monitor']
