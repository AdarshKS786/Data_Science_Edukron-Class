# %%
import pandas as pd
import numpy as np

# %%
pd.DataFrame([1,2,3],columns=['number'],index=[6,7,8])
# Out:
#    number
# 6       1
# 7       2
# 8       3

# %%
df=pd.DataFrame(np.random.randint(0,100,(4,4)),columns="A B C D".split(),index="P Q R S".split())

# %%
df
# Out:
#     A   B   C   D
# P  22  25  80  97
# Q  15  82  85  43
# R  82  76   6  54
# S  49  25  66   8

# %%
df=pd.DataFrame(np.random.randint(0,100,(10,6)))

# %%
data=[]
for i in range(1,11):
  data.append("student"+str(i))

# %%
data
# Out:
# ['student1',
#  'student2',
#  'student3',
#  'student4',
#  'student5',
#  'student6',
#  'student7',
#  'student8',
#  'student9',
#  'student10']

# %%
df.index=data

# %%
df
# Out:
#             0   1   2   3   4   5
# student1   70  14  16   1  37  49
# student2   71  86  23  11   9  60
# student3   27  72  15  61  19  82
# student4    8  67  50  23  45  68
# student5   35  83  81  88  78  81
# student6   80  45  90  37  95  37
# student7   28   1  83  29  76  33
# student8   85  96  33   5  98  31
# student9    6  55  16   6  83  65
# student10  51  93  90   6  67  66

# %%
data=[]
for i in range(1,7):
  data.append("subject"+str(i))

# %%
df.columns=data

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5  subject6
# student1         70        14        16         1        37        49
# student2         71        86        23        11         9        60
# student3         27        72        15        61        19        82
# student4          8        67        50        23        45        68
# student5         35        83        81        88        78        81
# student6         80        45        90        37        95        37
# student7         28         1        83        29        76        33
# student8         85        96        33         5        98        31
# student9          6        55        16         6        83        65
# student10        51        93        90         6        67        66

# %%
df.index
# Out:
# Index(['student1', 'student2', 'student3', 'student4', 'student5', 'student6',
#        'student7', 'student8', 'student9', 'student10'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['subject1', 'subject2', 'subject3', 'subject4', 'subject5', 'subject6'], dtype='object')

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5  subject6
# student1         70        14        16         1        37        49
# student2         71        86        23        11         9        60
# student3         27        72        15        61        19        82
# student4          8        67        50        23        45        68
# student5         35        83        81        88        78        81
# student6         80        45        90        37        95        37
# student7         28         1        83        29        76        33
# student8         85        96        33         5        98        31
# student9          6        55        16         6        83        65
# student10        51        93        90         6        67        66

# %%
df.shape
# Out:
# (10, 6)

# %%
df.values
# Out:
# array([[70, 14, 16,  1, 37, 49],
#        [71, 86, 23, 11,  9, 60],
#        [27, 72, 15, 61, 19, 82],
#        [ 8, 67, 50, 23, 45, 68],
#        [35, 83, 81, 88, 78, 81],
#        [80, 45, 90, 37, 95, 37],
#        [28,  1, 83, 29, 76, 33],
#        [85, 96, 33,  5, 98, 31],
#        [ 6, 55, 16,  6, 83, 65],
#        [51, 93, 90,  6, 67, 66]])

# %%
df.dtypes
# Out:
# subject1    int64
# subject2    int64
# subject3    int64
# subject4    int64
# subject5    int64
# subject6    int64
# dtype: object

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5  subject6
# student1         70        14        16         1        37        49
# student2         71        86        23        11         9        60
# student3         27        72        15        61        19        82
# student4          8        67        50        23        45        68
# student5         35        83        81        88        78        81
# student6         80        45        90        37        95        37
# student7         28         1        83        29        76        33
# student8         85        96        33         5        98        31
# student9          6        55        16         6        83        65
# student10        51        93        90         6        67        66

# %%
df.iloc[:3,-5:]
# Out:
#           subject2  subject3  subject4  subject5  subject6
# student1        14        16         1        37        49
# student2        86        23        11         9        60
# student3        72        15        61        19        82

# %%
df.iloc[:4,-3:]
# Out:
#           subject4  subject5  subject6
# student1         1        37        49
# student2        11         9        60
# student3        61        19        82
# student4        23        45        68

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5  subject6
# student1         70        14        16         1        37        49
# student2         71        86        23        11         9        60
# student3         27        72        15        61        19        82
# student4          8        67        50        23        45        68
# student5         35        83        81        88        78        81
# student6         80        45        90        37        95        37
# student7         28         1        83        29        76        33
# student8         85        96        33         5        98        31
# student9          6        55        16         6        83        65
# student10        51        93        90         6        67        66

# %%
df.iloc[0:4,0:4]
# Out:
#           subject1  subject2  subject3  subject4
# student1        70        14        16         1
# student2        71        86        23        11
# student3        27        72        15        61
# student4         8        67        50        23

# %%
df.loc["student1":"student4","subject1":"subject4"]
# Out:
#           subject1  subject2  subject3  subject4
# student1        70        14        16         1
# student2        71        86        23        11
# student3        27        72        15        61
# student4         8        67        50        23

# %%
df
# Out:
#            subject1  subject2  subject3  subject4  subject5  subject6
# student1         70        14        16         1        37        49
# student2         71        86        23        11         9        60
# student3         27        72        15        61        19        82
# student4          8        67        50        23        45        68
# student5         35        83        81        88        78        81
# student6         80        45        90        37        95        37
# student7         28         1        83        29        76        33
# student8         85        96        33         5        98        31
# student9          6        55        16         6        83        65
# student10        51        93        90         6        67        66

# %%
df["student1":"student2"]['subject1']
# Out:
# student1    70
# student2    71
# Name: subject1, dtype: int64

# %%
df.loc["student1":"student4","subject1":"subject4"]
# Out:
#           subject1  subject2  subject3  subject4
# student1        70        14        16         1
# student2        71        86        23        11
# student3        27        72        15        61
# student4         8        67        50        23

# %%
df=pd.read_excel("/content/Sample - Superstore.xls")

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df[df['Segment']=='Consumer']
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country             City  \
# 0       CG-12520       Claire Gute  Consumer  United States        Henderson
# ...

# %%
data=np.random.randint(0,7,5)

# %%
data
# Out:
# array([6, 3, 3, 1, 2])

# %%
data[data<5]
# Out:
# array([3, 3, 1, 2])

# %%
df[(df['Region']=='West') | (df['Category']=='Office Supplies')]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6          7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# 2       DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# ...

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df.select_dtypes(include='float').mean()
# Out:
# Sales       229.858001
# Discount      0.156203
# Profit       28.656896
# dtype: float64

# %%
df.select_dtypes(include='float').std()
# Out:
# Sales       623.245101
# Discount      0.206452
# Profit      234.260108
# dtype: float64

# %%
df.select_dtypes(include='float').max()
# Out:
# Sales       22638.480
# Discount        0.800
# Profit       8399.976
# dtype: float64

# %%
df.select_dtypes(include='float').var()
# Out:
# Sales       388434.455308
# Discount         0.042622
# Profit       54877.798055
# dtype: float64

# %%
df.select_dtypes(include='float').median()
# Out:
# Sales       54.4900
# Discount     0.2000
# Profit       8.6665
# dtype: float64

# %%
df.select_dtypes(include='float').quantile(0.50)
# Out:
# Sales       54.4900
# Discount     0.2000
# Profit       8.6665
# Name: 0.5, dtype: float64

# %%
df.select_dtypes(include='float').quantile(0.25)
# Out:
# Sales       17.28000
# Discount     0.00000
# Profit       1.72875
# Name: 0.25, dtype: float64

# %%
df.select_dtypes(include='float').quantile(0.75)
# Out:
# Sales       209.940
# Discount      0.200
# Profit       29.364
# Name: 0.75, dtype: float64

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.loc[:,["Sales","Region"]].groupby("Region").sum()
# Out:
#                Sales
# Region
# Central  501239.8908
# East     678781.2400
# South    391721.9050
# West     725457.8245

# %%
df.loc[:,["Sales","Region"]].groupby("Region").mean()
# Out:
#               Sales
# Region
# Central  215.772661
# East     238.336110
# South    241.803645
# West     226.493233

# %%
df.loc[:,["Sales","Region"]].groupby("Region").median()
# Out:
#           Sales
# Region
# Central  45.980
# East     54.900
# South    54.594
# West     60.840

# %%
df.shape
# Out:
# (9994, 21)
