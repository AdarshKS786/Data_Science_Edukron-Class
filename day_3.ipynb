# %%
x="Data"

# %%
len(x)
# Out:
# 4

# %%
x.upper()
# Out:
# 'DATA'

# %%
x="data science"
x.find("s")
# Out:
# 5

# %%
x="data science"
x.find("z")
# in this case it will return -1. Because it is not present in the string.
# Out:
# -1

# %%
# x="data science"
# x.index("x")
# in case index means it written as error. Because it is not present in the string.

# %%
x=" data "
len(x)
# Out:
# 6

# %%
x.strip()
# Out:
# 'data'

# %%
x.lstrip()
# Out:
# 'data '

# %%
x.rstrip()
# Out:
# ' data'

# %%
x.replace("d","xyz")
# Out:
# ' xyzata '

# %%
x="data"
x.center(8,"$")
# Out:
# '$$data$$'

# %%
x="20"
x.zfill(6)
# Out:
# '000020'

# %%
x='''data
science'''

# %%
x
# Out:
# 'data\nscience'

# %%
x.splitlines()
# Out:
# ['data', 'science']

# %%
x='data \nscience\adarsh'
x.splitlines()
# Out:
# ['data ', 'science\x07darsh']

# %%
"seperator".join(x)
# Out:
# 'dseperatoraseperatortseperatoraseperator seperator\nseperatorsseperatorcseperatoriseperatoreseperatornseperatorcseperatoreseperator\x07seperatordseperatoraseperatorrseperatorsseperatorh'

# %%
",".join("data")
# Out:
# 'd,a,t,a'

# %%
"_".join("hello")
# Out:
# 'h_e_l_l_o'

# %%
x=['data','science']
"".join(x)
# Out:
# 'datascience'

# %%
# list data types

# %%
x ="data"

# %%
x[-1].upper()[0:2]
# Out:
# 'A'

# %%
x[3].upper()[0:2]
# Out:
# 'A'

# %%
x=[1,2.6,(3+4j),'data']

# %%
x
# Out:
# [1, 2.6, (3+4j), 'data']

# %%
x[-1].upper()[0:2]
# Out:
# 'DA'

# %%
(x[1]+x[2])/2
# Out:
# (2.8+2j)

# %%
(x[0]+x[1])/2
# Out:
# 1.8

# %%
x=[1,2,3,4,5]

# %%
x[-1]+x[1]
# Out:
# 7

# %%
x[-2]/x[2]
# Out:
# 1.3333333333333333

# %%
x=[1,2,3,4,[1,2,3,4,[5,6,7]]]

# %%
x
# Out:
# [1, 2, 3, 4, [1, 2, 3, 4, [5, 6, 7]]]

# %%
x=["data", "science", "machine", "learning", [1,2,3]]

# %%
x
# Out:
# ['data', 'science', 'machine', 'learning', [1, 2, 3]]

# %%
x[-1]
# Out:
# [1, 2, 3]

# %%
x=["data", "science", ["machine", "learning", ]]

# %%
len(x)
# Out:
# 3

# %%
x[-1]
# Out:
# ['machine', 'learning']

# %%
x[-1][-1]
# Out:
# 'learning'

# %%
x[2][-2][-3:].upper()
# Out:
# 'INE'

# %%
customers = [
    ["Ravi", ["shampoo", "toothpaste "]],
    ["anjali", ["Rice", "Wheat","Oil"]],
    ["Kiran", ["Biscuits", "Milk"]]
]

# %%
customers
# Out:
# [['Ravi', ['shampoo', 'toothpaste ']],
#  ['anjali', ['Rice', 'Wheat', 'Oil']],
#  ['Kiran', ['Biscuits', 'Milk']]]

# %%
customers[1][-1][-1]
# Out:
# 'Oil'

# %%
customers[2][1][0]
# Out:
# 'Biscuits'

# %%
customers[2][-1][-2]
# Out:
# 'Biscuits'

# %%
performance = [
 ["Surath",[["Nikitha",85],["Arun", 78]]],
 ["Pune", [["Rohit", 90], ["Swati", 88]]]
 ]

# %%
performance
# Out:
# [['Surath', [['Nikitha', 85], ['Arun', 78]]],
#  ['Pune', [['Rohit', 90], ['Swati', 88]]]]

# %%
performance[0][-1][-1][-1] + performance[1][-1][-1][-1]
# Out:
# 166

# %%
len(performance)
# Out:
# 2

# %%
x=[1,2,3,4]

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
x.append(20)

# %%
x
# Out:
# [1, 2, 3, 4, 20]

# %%
x.extend("DATA")

# %%
x
# Out:
# [1, 2, 3, 4, 20, 'D', 'A', 'T', 'A']

# %%
x=[1,2,3]
y=[4,5,6]

# %%
x.append(y)

# %%
x
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
x=[1,2,3]
y=[4,5,6]
x.extend(y)

# %%
x
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x=[1,2,3,4]

# %%
x.insert(-1, "data")

# %%
x
# Out:
# [1, 2, 3, 'data', 4]

# %%
x.pop(2)
# Out:
# 3

# %%
x.remove(2)

# %%
x=[1,2,3,4]

# %%
x.remove(2)

# %%
x
# Out:
# [1, 3, 4]

# %%
x=[1,2,2,2,2,3,4,5]
x.count(2)
# Out:
# 4

# %%
x.index(5,3)
# Out:
# 7

# %%
weekly_sales=[
    ["chennai",[12000,15000,17000]],
    ["Delhi",[10000,11000,10500]],
    ["Kolkata",[9000,9500,9800]]
]

# %%
weekly_sales[0][1][1]
# Out:
# 15000

# %%
weekly_sales[0][1][1]
# Out:
# 15000

# %%
weekly_sales
# Out:
# [['chennai', [12000, 15000, 17000]],
#  ['Delhi', [10000, 11000, 10500]],
#  ['Kolkata', [9000, 9500, 9800]]]

# %%
weekly_sales[0][1][-1]
# Out:
# 17000

# %%
weekly_sales[1][1][0]
# Out:
# 10000

# %%
weekly_sales[1][1][1]
# Out:
# 11000

# %%
weekly_sales
# Out:
# [['chennai', [12000, 15000, 17000]],
#  ['Delhi', [10000, 11000, 10500]],
#  ['Kolkata', [9000, 9500, 9800]]]

# %%
weekly_sales[1][1][-1]
# Out:
# 10500

# %%
weekly_sales[2][1][0]
# Out:
# 9000

# %%
weekly_sales
# Out:
# [['chennai', [12000, 15000, 17000]],
#  ['Delhi', [10000, 11000, 10500]],
#  ['Kolkata', [9000, 9500, 9800]]]

# %%
weekly_sales[2][1][1]
# Out:
# 9500

# %%
weekly_sales[2][1][-1]
# Out:
# 9800

# %%
weekly_sales
# Out:
# [['chennai', [12000, 15000, 17000]],
#  ['Delhi', [10000, 11000, 10500]],
#  ['Kolkata', [9000, 9500, 9800]]]

# %%
weekly_sales[0][0], weekly_sales[1][0], weekly_sales[2][0]
# Out:
# ('chennai', 'Delhi', 'Kolkata')

# %%
weekly_sales[0][1][0] +weekly_sales[0][1][1]+weekly_sales[0][1][-1]
# Out:
# 44000

# %%
weekly_sales[1][1][0] +weekly_sales[1][1][1]+weekly_sales[1][1][-1]
# Out:
# 31500

# %%
weekly_sales[2][1][0] +weekly_sales[2][1][1]+weekly_sales[2][1][-1]
# Out:
# 28300

# %%
weekly_sales
# Out:
# [['chennai', [12000, 15000, 17000]],
#  ['Delhi', [10000, 11000, 10500]],
#  ['Kolkata', [9000, 9500, 9800]]]

# %%
weekly_sales[0][1][0] +weekly_sales[0][1][1]+weekly_sales[0][1][-1]/3
# Out:
# 32666.666666666668
